# %% [markdown]
# ### Exploratory Data Analysis: Healthcare Data from Maven Analytics
#
# This detailed EDA focuses on patient-level data sourced from Maven Analytics, representing approximately 900 patients from a healthcare institute in Boston. It's important to note that the records are synthetic and do not reflect actual patient data. The primary objectives of this EDA include understanding the data structure of the table, transforming it into more PowerBI-friendly flat files, and gaining insights into what the data represents. Key aspects of the analysis include basic counts, data integrity checks, and distinguishing between Oncology and Non-Oncology data segments where applicable.
#
# The analysis will cover:
# - Data structure overview and transformation for PowerBI compatibility.
# - Basic statistical summaries and distributions.
# - Sanity checks to ensure data reliability.
# - Segmentation and analysis between Oncology and Non-Oncology patient groups.
#
# This EDA aims to provide a comprehensive understanding of the dataset's characteristics and insights into healthcare trends within the Boston healthcare institute context.

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 100)

# %%
# Read the CSV files to understand the data structure of the flat files, starting with the data dictionary

data_dict = pd.read_csv("data_dictionary.csv")
encounters = pd.read_csv("encounters.csv")
organizations = pd.read_csv("organizations.csv")
patients = pd.read_csv("patients.csv")
payers = pd.read_csv("payers.csv")
procedures = pd.read_csv("procedures.csv")

# %% [markdown]
# ### Understand the data structure of each table
# Also explore some fields

# %%
# Data Dictionary
data_dict.head(2)
# Out:
#       Table      Field                                     Description
# 0  patients         Id  Primary Key. Unique Identifier of the patient.
# 1  patients  BIRTHDATE     The date (YYYY-MM-DD) the patient was born.

# %%
# These are the names of the tables we will work with 
set(data_dict.Table.to_list())
# Out:
# {'encounters', 'organizations', 'patients', 'payers', 'procedures'}

# %% [markdown]
# ##### Encounters Table
# Records containing each de-identified patient visit to the facility

# %%
encounters.head(2)
# Out:
#                                      Id       START        STOP  CLAIM_YEAR  \
# 0  32c84703-2481-49cd-d571-3899d5820253  02-01-2011  02-01-2011        2011
# 1  c98059da-320a-c0a6-fced-c8815f3e3f39  03-01-2011  03-01-2011        2011
#
#    CLAIM_MONTH                               PATIENT  \
# 0            1  3de74169-7f67-9304-91d4-757e0f3a14d2
# 1            1  d9ec2e44-32e9-9148-179a-1653348cc4e2
#
#                            ORGANIZATION                                 PAYER  \
# 0  d78e84ec-30aa-3bba-a33a-f29a3a454662  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 1  d78e84ec-30aa-3bba-a33a-f29a3a454662  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
#
#   ENCOUNTERCLASS       CODE                        DESCRIPTION  \
# 0     ambulatory  185347001  Encounter for problem (procedure)
# 1     outpatient  308335008        Patient encounter procedure
#
#    BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE  \
# 0                85.55           1018.02             0.0         NaN
# 1               142.58           2619.36             0.0         NaN
#
#   REASONDESCRIPTION
# 0               NaN
# 1               NaN

# %%
print(f"Shape of the encounters table: {encounters.shape}")
print(f"Columns in the encounter table: {encounters.columns}")
print(f"Number of Unique Patients: {encounters.PATIENT.nunique()}\n-------------")
# Out:
# Shape of the encounters table: (27891, 16)
# Columns in the encounter table: Index(['Id', 'START', 'STOP', 'CLAIM_YEAR', 'CLAIM_MONTH', 'PATIENT',
#        'ORGANIZATION', 'PAYER', 'ENCOUNTERCLASS', 'CODE', 'DESCRIPTION',
#        'BASE_ENCOUNTER_COST', 'TOTAL_CLAIM_COST', 'PAYER_COVERAGE',
#        'REASONCODE', 'REASONDESCRIPTION'],
#       dtype='object')
# Number of Unique Patients: 974
# -------------

# %%
# Basic Data Points to note
print(f"Number of Unique Encounters: {encounters.Id.nunique()}")
print(f"Since this is the same as number of rows, this means no duplicates are found in the Encounter IDs \n-------------")
print(f"Unique values of Encounters Class: {encounters.ENCOUNTERCLASS.unique()}\n-------------")
print(f"Example values of Diagnoses: {encounters.REASONDESCRIPTION.unique()[1:6]}\n-------------")
# Out:
# Number of Unique Encounters: 27891
# Since this is the same as number of rows, this means no duplicates are found in the Encounter IDs
# -------------
# Unique values of Encounters Class: ['ambulatory' 'outpatient' 'wellness' 'urgentcare' 'inpatient' 'emergency']
# -------------
# Example values of Diagnoses: ['Hyperlipidemia' 'Malignant tumor of colon'
#  'Non-small cell lung cancer (disorder)'
#  'Non-small cell carcinoma of lung  TNM stage 1 (disorder)'
#  'Acute bronchitis (disorder)']
# -------------

# %% [markdown]
# ##### Organisation Table
# Since this data set only has data from 1 hospital, this table doesn't serve much purpose

# %%
organizations.head(2)
# Out:
#                                      Id                            NAME  \
# 0  d78e84ec-30aa-3bba-a33a-f29a3a454662  MASSACHUSETTS GENERAL HOSPITAL
#
#            ADDRESS    CITY STATE   ZIP        LAT        LON
# 0  55 FRUIT STREET  BOSTON    MA  2114  42.362813 -71.069187

# %% [markdown]
# ##### Patients Table
# The original table contained patient names as well. However despite being synthetic data, to comply with Patient privacy (HIPPA compliance) and adhering to industry standards, the columns were dropped.

# %%
patients.head(2)
# Out:
#                                      Id   BIRTHDATE  YEAR_OF_BIRTH DEATHDATE  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f  19-03-1977           1977       NaN
# 1  6e5ae27c-8038-7988-e2c0-25a103f01bfa  19-02-1940           1940       NaN
#
#   MARITAL   RACE    ETHNICITY GENDER                    BIRTHPLACE  \
# 0       M  white  nonhispanic      F  Wakefield  Massachusetts  US
# 1       M  white  nonhispanic      M  Brookline  Massachusetts  US
#
#                       ADDRESS    CITY          STATE          COUNTY     ZIP  \
# 0  510 Little Station Unit 69  Quincy  Massachusetts  Norfolk County  2186.0
# 1         747 Conn Throughway  Boston  Massachusetts  Suffolk County  2135.0
#
#          LAT        LON
# 0  42.290937 -70.975503
# 1  42.308831 -71.063162

# %%
print(f"Shape of the patient table: {patients.shape}")
print(f"Columns in the patient table: {patients.columns}\n-------------")
# Out:
# Shape of the patient table: (974, 16)
# Columns in the patient table: Index(['Id', 'BIRTHDATE', 'YEAR_OF_BIRTH', 'DEATHDATE', 'MARITAL', 'RACE',
#        'ETHNICITY', 'GENDER', 'BIRTHPLACE', 'ADDRESS', 'CITY', 'STATE',
#        'COUNTY', 'ZIP', 'LAT', 'LON'],
#       dtype='object')
# -------------

# %%
# Basic Data Points to note (Patient Demographics)
print(f"Summary of Patient: {patients.RACE.value_counts()}\n-------------")
print(f"Summary of Patient: {patients.GENDER.value_counts()}\n-------------")
print(f"Summary of Patient: {patients.ETHNICITY.value_counts()}\n-------------")
# Out:
# Summary of Patient: RACE
# white       680
# black       163
# asian        91
# other        16
# hawaiian     13
# native       11
# Name: count, dtype: int64
# -------------
# Summary of Patient: GENDER
# M    494
# F    480
# Name: count, dtype: int64
# -------------
# Summary of Patient: ETHNICITY
# nonhispanic    783
# hispanic       191
# Name: count, dtype: int64
# -------------

# %% [markdown]
# ##### Payers Table
# Which was the insurance the patients were on? Can be used through the Payer ID In the encounter table

# %%
payers.head(2)
# Out:
#                                      Id           NAME             ADDRESS  \
# 0  b3221cfc-24fb-339e-823d-bc4136cbc4ed  Dual Eligible  7500 Security Blvd
# 1  7caa7254-5050-3b5e-9eae-bd5ea30e809c       Medicare  7500 Security Blvd
#
#         CITY STATE_HEADQUARTERED      ZIP           PHONE
# 0  Baltimore                  MD  21244.0  1-877-267-2323
# 1  Baltimore                  MD  21244.0  1-800-633-4227

# %%
print(f"Shape of the payers table: {payers.shape}")
print("Columns in the payers table: ")
print(payers.columns)
# Out:
# Shape of the payers table: (10, 7)
# Columns in the payers table:
# Index(['Id', 'NAME', 'ADDRESS', 'CITY', 'STATE_HEADQUARTERED', 'ZIP', 'PHONE'], dtype='object')

# %%
# Basic Data Points to note (Payer Details)
print(f"Payor Names: {payers.NAME.unique()}\n-------------")
print(f"Payor HQs: {payers.STATE_HEADQUARTERED.unique()}\n-------------")
# Out:
# Payor Names: ['Dual Eligible' 'Medicare' 'Medicaid' 'Humana' 'Blue Cross Blue Shield'
#  'UnitedHealthcare' 'Aetna' 'Cigna Health' 'Anthem' 'NO_INSURANCE']
# -------------
# Payor HQs: ['MD' 'KY' 'IL' 'MN' 'CT' 'IN' nan]
# -------------

# %% [markdown]
# ##### Procedures Table
# On each encounter, whether a procedure took place? This might be including MedProcs like Cancer Surgery, Biopsies, Tests and many more

# %%
procedures.head(2)
# Out:
#         START        STOP  PROC_YEAR  PROC_MONTH  \
# 0  2011-01-02  2011-01-02       2011           1
# 1  2011-01-03  2011-01-03       2011           1
#
#                                 PATIENT                             ENCOUNTER  \
# 0  3de74169-7f67-9304-91d4-757e0f3a14d2  32c84703-2481-49cd-d571-3899d5820253
# 1  d9ec2e44-32e9-9148-179a-1653348cc4e2  c98059da-320a-c0a6-fced-c8815f3e3f39
#
#           CODE                 DESCRIPTION  BASE_COST  REASONCODE  \
# 0  265764009.0  Renal dialysis (procedure)        903         NaN
# 1   76601001.0     Intramuscular injection       2477         NaN
#
#   REASONDESCRIPTION
# 0               NaN
# 1               NaN

# %%
print(f"Shape of the procedures table: {procedures.shape}")
print(f"Columns in the procedures table: {procedures.columns}")
# Out:
# Shape of the procedures table: (47701, 11)
# Columns in the procedures table: Index(['START', 'STOP', 'PROC_YEAR', 'PROC_MONTH', 'PATIENT', 'ENCOUNTER',
#        'CODE', 'DESCRIPTION', 'BASE_COST', 'REASONCODE', 'REASONDESCRIPTION'],
#       dtype='object')

# %%
# Basic Data Points to note (Proc Details)
print(f"Examples of Procedure Reason (Diagnosis): {procedures.REASONDESCRIPTION.unique()[1:6]}\n-------------")
print(f"Example values of Procedures performed: {procedures.DESCRIPTION.unique()[1:6]}\n-------------")
# Out:
# Examples of Procedure Reason (Diagnosis): ['Malignant tumor of colon' 'Suspected lung cancer (situation)'
#  'Non-small cell carcinoma of lung  TNM stage 1 (disorder)'
#  'Atrial Fibrillation' 'Normal pregnancy']
# -------------
# Example values of Procedures performed: ['Intramuscular injection'
#  'Combined chemotherapy and radiation therapy (procedure)'
#  'Diagnostic fiberoptic bronchoscopy (procedure)'
#  'Digital examination of rectum'
#  'Magnetic resonance imaging for measurement of brain volume (procedure)']
# -------------

# %% [markdown]
# ### Fill Rate Analysis (Data Sanity Checks)
# After giving each table a look, we know that the data is clean and free of any loading errors (from the perspective of industry grade data lakes)
# The columns are not out of orders, each parameter in every column makes sense, the Primary keys are a perfect match when performing joins.
#
# A final sanity check we can perform is fill rates analysis

# %%
my_dict = {
    'patients': set(patients.columns),
    'procedures': set(procedures.columns),
    'encounters': set(encounters.columns),
    'payers': set(payers.columns)
}

# %%
#Print out all the Tables and Column Values

for key, value in my_dict.items():
    print(f"Key: {key}, Value: {value}")
# Out:
# Key: patients, Value: {'BIRTHDATE', 'ETHNICITY', 'Id', 'RACE', 'ZIP', 'YEAR_OF_BIRTH', 'LON', 'BIRTHPLACE', 'MARITAL', 'GENDER', 'STATE', 'COUNTY', 'DEATHDATE', 'CITY', 'ADDRESS', 'LAT'}
# Key: procedures, Value: {'CODE', 'DESCRIPTION', 'PROC_MONTH', 'REASONCODE', 'PROC_YEAR', 'START', 'PATIENT', 'BASE_COST', 'STOP', 'ENCOUNTER', 'REASONDESCRIPTION'}
# Key: encounters, Value: {'CODE', 'DESCRIPTION', 'CLAIM_YEAR', 'Id', 'ORGANIZATION', 'REASONCODE', 'PAYER', 'BASE_ENCOUNTER_COST', 'PAYER_COVERAGE', 'START', 'CLAIM_MONTH', 'PATIENT', 'ENCOUNTERCLASS', 'STOP', 'TOTAL_CLAIM_COST', 'REASONDESCRIPTION'}
# Key: payers, Value: {'NAME', 'Id', 'PHONE', 'ZIP', 'STATE_HEADQUARTERED', 'CITY', 'ADDRESS'}

# %%
df_fill_rate = pd.DataFrame(columns=['Table', 'Field', 'Total Rows', 'Filled Rows', 'Fill Rate'])
# Calculate FIll rates seperately, and then make a final single table

# 1] Calculate Fill Rates for the patients table
for column_name in patients.columns:
    my_dict = {
        'Table': 'patients',
        'Field': f"{column_name}",
        'Total Rows': len(patients[f"{column_name}"]),
        'Filled Rows': patients[f"{column_name}"].count(),
        'Fill Rate': (patients[f"{column_name}"].count() / len(patients[f"{column_name}"])) * 100    # Example values
    }
    df_i = pd.DataFrame(columns=['Table', 'Column', 'Total Rows', 'Filled Rows', 'Fill Rate'])
    df_i = pd.DataFrame([my_dict])
    df_fill_rate = pd.concat([df_fill_rate, df_i], ignore_index=True)

# 2] Calculate Fill Rates for the procedures table
for column_name in procedures.columns:
    my_dict = {
        'Table': 'procedures',
        'Field': f"{column_name}",
        'Total Rows': len(procedures[f"{column_name}"]),
        'Filled Rows': procedures[f"{column_name}"].count(),
        'Fill Rate': (procedures[f"{column_name}"].count() / len(procedures[f"{column_name}"])) * 100
    }
    df_i = pd.DataFrame(columns=['Table', 'Column', 'Total Rows', 'Filled Rows', 'Fill Rate'])
    df_i = pd.DataFrame([my_dict])
    df_fill_rate = pd.concat([df_fill_rate, df_i], ignore_index=True)

# 3] Calculate Fill Rates for the payors table
for column_name in payers.columns:
    my_dict = {
        'Table': 'payers',
        'Field': f"{column_name}",
        'Total Rows': len(payers[f"{column_name}"]),
        'Filled Rows': payers[f"{column_name}"].count(),
        'Fill Rate': (payers[f"{column_name}"].count() / len(payers[f"{column_name}"])) * 100
    }
    df_i = pd.DataFrame(columns=['Table', 'Column', 'Total Rows', 'Filled Rows', 'Fill Rate'])
    df_i = pd.DataFrame([my_dict])
    df_fill_rate = pd.concat([df_fill_rate, df_i], ignore_index=True)

# 4] Calculate Fill Rates for the organizations table
for column_name in organizations.columns:
    my_dict = {
        'Table': 'organizations',
        'Field': f"{column_name}",
        'Total Rows': len(organizations[f"{column_name}"]),
        'Filled Rows': organizations[f"{column_name}"].count(),
        'Fill Rate': (organizations[f"{column_name}"].count() / len(organizations[f"{column_name}"])) * 100
    }
    df_i = pd.DataFrame(columns=['Table', 'Column', 'Total Rows', 'Filled Rows', 'Fill Rate'])
    df_i = pd.DataFrame([my_dict])
    df_fill_rate = pd.concat([df_fill_rate, df_i], ignore_index=True)

# 5] Calculate Fill Rates for the encounters table
for column_name in encounters.columns:
    my_dict = {
        'Table': 'encounters',
        'Field': f"{column_name}",
        'Total Rows': len(encounters[f"{column_name}"]),
        'Filled Rows': encounters[f"{column_name}"].count(),
        'Fill Rate': (encounters[f"{column_name}"].count() / len(encounters[f"{column_name}"])) * 100
    }
    df_i = pd.DataFrame(columns=['Table', 'Field', 'Total Rows', 'Filled Rows', 'Fill Rate'])
    df_i = pd.DataFrame([my_dict])
    df_fill_rate = pd.concat([df_fill_rate, df_i], ignore_index=True)
# Out:
# C:\Users\shant\AppData\Local\Temp\ipykernel_18068\3561849006.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_fill_rate = pd.concat([df_fill_rate, df_i], ignore_index=True)

# %%
# Merge Above result with Data Dictionary to get a final table
df_fill_rate_final = pd.merge(df_fill_rate, data_dict, on = ['Table', 'Field'], how='left')
df_fill_rate_final = df_fill_rate_final[['Table', 'Field', 'Total Rows', 'Filled Rows', 'Fill Rate', 'Description']]
df_fill_rate_final.to_csv('Fill_Rates.csv', index = False)
df_fill_rate_final
# Out:
#             Table                Field Total Rows Filled Rows   Fill Rate  \
# 0        patients                   Id        974         974  100.000000
# 1        patients            BIRTHDATE        974         974  100.000000
# 2        patients        YEAR_OF_BIRTH        974         974  100.000000
# 3        patients            DEATHDATE        974         154   15.811088
# 4        patients              MARITAL        974         973   99.897331
# 5        patients                 RACE        974         974  100.000000
# 6        patients            ETHNICITY        974         974  100.000000
# 7        patients               GENDER        974         974  100.000000
# 8        patients           BIRTHPLACE        974         974  100.000000
# 9        patients              ADDRESS        974         974  100.000000
# 10       patients                 CITY        974         974  100.000000
# 11       patients                STATE        974         974  100.000000
# 12       patients               COUNTY        974         974  100.000000
# 13       patients                  ZIP        974         832   85.420945
# 14       patients                  LAT        974         974  100.000000
# 15       patients                  LON        974         974  100.000000
# 16     procedures                START      47701       47701  100.000000
# 17     procedures                 STOP      47701       47701  100.000000
# 18     procedures            PROC_YEAR      47701       47701  100.000000
# 19     procedures           PROC_MONTH      47701       47701  100.000000
# 20     procedures              PATIENT      47701       47701  100.000000
# 21     procedures            ENCOUNTER      47701       47701  100.000000
# 22     procedures                 CODE      47701       47701  100.000000
# 23     procedures          DESCRIPTION      47701       47701  100.000000
# 24     procedures            BASE_COST      47701       47701  100.000000
# 25     procedures           REASONCODE      47701       10756   22.548794
# 26     procedures    REASONDESCRIPTION      47701       10756   22.548794
# 27         payers                   Id         10          10  100.000000
# 28         payers                 NAME         10          10  100.000000
# 29         payers              ADDRESS         10           9   90.000000
# 30         payers                 CITY         10           9   90.000000
# 31         payers  STATE_HEADQUARTERED         10           9   90.000000
# 32         payers                  ZIP         10           9   90.000000
# 33         payers                PHONE         10           9   90.000000
# 34  organizations                   Id          1           1  100.000000
# 35  organizations                 NAME          1           1  100.000000
# 36  organizations              ADDRESS          1           1  100.000000
# 37  organizations                 CITY          1           1  100.000000
# 38  organizations                STATE          1           1  100.000000
# 39  organizations                  ZIP          1           1  100.000000
# 40  organizations                  LAT          1           1  100.000000
# 41  organizations                  LON          1           1  100.000000
# 42     encounters                   Id      27891       27891  100.000000
# 43     encounters                START      27891       27891  100.000000
# 44     encounters                 STOP      27891       27891  100.000000
# 45     encounters           CLAIM_YEAR      27891       27891  100.000000
# 46     encounters          CLAIM_MONTH      27891       27891  100.000000
# 47     encounters              PATIENT      27891       27891  100.000000
# 48     encounters         ORGANIZATION      27891       27891  100.000000
# 49     encounters                PAYER      27891       27891  100.000000
# 50     encounters       ENCOUNTERCLASS      27891       27891  100.000000
# 51     encounters                 CODE      27891       27891  100.000000
# 52     encounters          DESCRIPTION      27891       27891  100.000000
# 53     encounters  BASE_ENCOUNTER_COST      27891       27891  100.000000
# 54     encounters     TOTAL_CLAIM_COST      27891       27891  100.000000
# 55     encounters       PAYER_COVERAGE      27891       27891  100.000000
# 56     encounters           REASONCODE      27891        8350   29.937973
# 57     encounters    REASONDESCRIPTION      27891        8350   29.937973
#
#                                           Description
# 0      Primary Key. Unique Identifier of the patient.
# 1         The date (YYYY-MM-DD) the patient was born.
# 2                             Patient's Year of Birth
# 3             The date (YYYY-MM-DD) the patient died.
# 4   Marital Status. M is married, S is single. Cur...
# 5          Description of the patient's primary race.
# 6     Description of the patient's primary ethnicity.
# 7                     Gender. M is male, F is female.
# 8        Name of the town where the patient was born.
# 9   Patient's street address without commas or new...
# 10                            Patient's address city.
# 11                           Patient's address state.
# 12                          Patient's address county.
# 13                                Patient's zip code.
# 14                     Latitude of Patient's address.
# 15                    Longitude of Patient's address.
# 16  The date and time (iso8601 UTC Date (yyyy-MM-d...
# 17  The date and time (iso8601 UTC Date (yyyy-MM-d...
# 18                                     Procedure Year
# 19                                    Procedure Month
# 20                        Foreign key to the Patient.
# 21  Foreign key to the Encounter where the procedu...
# 22                      Procedure code from SNOMED-CT
# 23                      Description of the procedure.
# 24               The line item cost of the procedure.
# 25  Diagnosis code from SNOMED-CT specifying why t...
# 26                    Description of the reason code.
# 27         Primary key of the Payer (e.g. Insurance).
# 28                                 Name of the Payer.
# 29  Payer's street address without commas or newli...
# 30                               Street address city.
# 31                 Street address state abbreviation.
# 32                 Street address zip or postal code.
# 33                              Payer's phone number.
# 34                   Primary key of the Organization.
# 35                          Name of the Organization.
# 36  Organization's street address without commas o...
# 37                               Street address city.
# 38                 Street address state abbreviation.
# 39                 Street address zip or postal code.
# 40                Latitude of Organization's address.
# 41               Longitude of Organization's address.
# 42   Primary Key. Unique Identifier of the encounter.
# 43  The date and time (iso8601 UTC Date (yyyy-MM-d...
# 44  The date and time (iso8601 UTC Date (yyyy-MM-d...
# 45                                     Encounter Year
# 46                                    Encounter Month
# 47                        Foreign key to the Patient.
# 48                   Foreign key to the Organization.
# 49                          Foreign key to the Payer.
# 50  The class of the encounter, such as ambulatory...
# 51                      Encounter code from SNOMED-CT
# 52              Description of the type of encounter.
# 53  The base cost of the encounter, not including ...
# 54  The total cost of the encounter, including all...
# 55           The amount of cost covered by the Payer.
# 56  Diagnosis code from SNOMED-CT, only if this en...
# 57                    Description of the reason code.

# %% [markdown]
# ### Data Attribute Analysis
# This section will explore tha actual numbers in this dataset, the various splits, the patient population, the demographic distribution, analysis of the diagnosis and procedures that the patient undergoes etc.

# %% [markdown]
# #### 1. Patient Attributes and Demographics: According to diagnosis types (Cancer vs Non Cancer)
#
# Join the encounter table with the patients table; also manually assign each diagnosis type into cancer vs non cancer (external CSV for exact mapping)

# %%
diag_rollup_map = pd.read_csv("diagnosis_rollup.csv")
diag_rollup_map
# Out:
#                                          disease_name  \
# 0                            Malignant tumor of colon
# 1               Non-small cell lung cancer (disorder)
# 2   Non-small cell carcinoma of lung  TNM stage 1 ...
# 3   Primary small cell malignant neoplasm of lung ...
# 4             Malignant neoplasm of breast (disorder)
# 5                 Primary malignant neoplasm of colon
# 6             Overlapping malignant neoplasm of colon
# 7                                Neoplasm of prostate
# 8                   Suspected lung cancer (situation)
# 9             Small cell carcinoma of lung (disorder)
# 10              Secondary malignant neoplasm of colon
# 11                                     Hyperlipidemia
# 12                        Acute bronchitis (disorder)
# 13                         Viral sinusitis (disorder)
# 14                                   Normal pregnancy
# 15                    Fetus with unknown complication
# 16                     Alzheimer's disease (disorder)
# 17                                      Drug overdose
# 18                      Primary fibromyalgia syndrome
# 19                                             Asthma
# 20        Chronic congestive heart failure (disorder)
# 21                                  Anemia (disorder)
# 22                 Acute viral pharyngitis (disorder)
# 23                               Fracture of clavicle
# 24                                Fracture of forearm
# 25                                  Fracture of ankle
# 26      Localized  primary osteoarthritis of the hand
# 27                                 Contact dermatitis
# 28                                 Bleeding from anus
# 29               Acute bacterial sinusitis (disorder)
# 30  Familial Alzheimer's disease of early onset (d...
# 31                                    Fracture of rib
# 32                                  Sepsis (disorder)
# 33                               Sinusitis (disorder)
# 34                             Osteoarthritis of knee
# 35                                       Chronic pain
# 36               Streptococcal sore throat (disorder)
# 37           Concussion with no loss of consciousness
# 38               Injury of anterior cruciate ligament
# 39               Laparoscopic Removal of Gall Bladder
# 40                             Closed fracture of hip
# 41                               Rheumatoid arthritis
# 42                      Fracture subluxation of wrist
# 43       Injury of medial collateral ligament of knee
# 44                 Fetus with chromosomal abnormality
# 45           Escherichia coli urinary tract infection
# 46                 Idiopathic atrophic hypothyroidism
# 47                                  First degree burn
# 48                                 Second degree burn
# 49                                      Blighted ovum
# 50                                             Stroke
# 51                              Osteoarthritis of hip
# 52                                       Bullet wound
# 53   Injury of tendon of the rotator cuff of shoulder
# 54                                           Cystitis
# 55                                          Pneumonia
# 56              Concussion with loss of consciousness
# 57                                     Polyp of colon
# 58                                    Impacted molars
# 59                                Acute Cholecystitis
# 60                                       Otitis media
# 61                            Opioid abuse (disorder)
# 62                         Rupture of patellar tendon
# 63                              Myocardial Infarction
# 64                                       Appendicitis
# 65                                     Cardiac Arrest
# 66                                  Third degree burn
# 67          Chronic intractable migraine without aura
# 68                                               Gout
# 69                                       Hypertension
# 70                      Posttraumatic stress disorder
# 71  Fracture of vertebral column without spinal co...
# 72                                           COVID-19
#
#                                                rollup rollup_category
# 0                                        Colon Cancer          Cancer
# 1                                 Lung Cancer (NSCLC)          Cancer
# 2                                 Lung Cancer (NSCLC)          Cancer
# 3                                  Lung Cancer (SCLC)          Cancer
# 4                                       Breast Cancer          Cancer
# 5                                        Colon Cancer          Cancer
# 6                                        Colon Cancer          Cancer
# 7                                     Prostate Cancer          Cancer
# 8                                         Lung Cancer          Cancer
# 9                                  Lung Cancer (SCLC)          Cancer
# 10                                       Colon Cancer          Cancer
# 11                                     Hyperlipidemia      Non-Cancer
# 12                        Acute bronchitis (disorder)      Non-Cancer
# 13                         Viral sinusitis (disorder)      Non-Cancer
# 14                                   Normal pregnancy      Non-Cancer
# 15                    Fetus with unknown complication      Non-Cancer
# 16                     Alzheimer's disease (disorder)      Non-Cancer
# 17                                      Drug overdose      Non-Cancer
# 18                      Primary fibromyalgia syndrome      Non-Cancer
# 19                                             Asthma      Non-Cancer
# 20        Chronic congestive heart failure (disorder)      Non-Cancer
# 21                                  Anemia (disorder)      Non-Cancer
# 22                 Acute viral pharyngitis (disorder)      Non-Cancer
# 23                               Fracture of clavicle      Non-Cancer
# 24                                Fracture of forearm      Non-Cancer
# 25                                  Fracture of ankle      Non-Cancer
# 26      Localized  primary osteoarthritis of the hand      Non-Cancer
# 27                                 Contact dermatitis      Non-Cancer
# 28                                 Bleeding from anus      Non-Cancer
# 29               Acute bacterial sinusitis (disorder)      Non-Cancer
# 30  Familial Alzheimer's disease of early onset (d...      Non-Cancer
# 31                                    Fracture of rib      Non-Cancer
# 32                                  Sepsis (disorder)      Non-Cancer
# 33                               Sinusitis (disorder)      Non-Cancer
# 34                             Osteoarthritis of knee      Non-Cancer
# 35                                       Chronic pain      Non-Cancer
# 36               Streptococcal sore throat (disorder)      Non-Cancer
# 37           Concussion with no loss of consciousness      Non-Cancer
# 38               Injury of anterior cruciate ligament      Non-Cancer
# 39               Laparoscopic Removal of Gall Bladder      Non-Cancer
# 40                             Closed fracture of hip      Non-Cancer
# 41                               Rheumatoid arthritis      Non-Cancer
# 42                      Fracture subluxation of wrist      Non-Cancer
# 43       Injury of medial collateral ligament of knee      Non-Cancer
# 44                 Fetus with chromosomal abnormality      Non-Cancer
# 45           Escherichia coli urinary tract infection      Non-Cancer
# 46                 Idiopathic atrophic hypothyroidism      Non-Cancer
# 47                                  First degree burn      Non-Cancer
# 48                                 Second degree burn      Non-Cancer
# 49                                      Blighted ovum      Non-Cancer
# 50                                             Stroke      Non-Cancer
# 51                              Osteoarthritis of hip      Non-Cancer
# 52                                       Bullet wound      Non-Cancer
# 53   Injury of tendon of the rotator cuff of shoulder      Non-Cancer
# 54                                           Cystitis      Non-Cancer
# 55                                          Pneumonia      Non-Cancer
# 56              Concussion with loss of consciousness      Non-Cancer
# 57                                     Polyp of colon      Non-Cancer
# 58                                    Impacted molars      Non-Cancer
# 59                                Acute Cholecystitis      Non-Cancer
# 60                                       Otitis media      Non-Cancer
# 61                            Opioid abuse (disorder)      Non-Cancer
# 62                         Rupture of patellar tendon      Non-Cancer
# 63                              Myocardial Infarction      Non-Cancer
# 64                                       Appendicitis      Non-Cancer
# 65                                     Cardiac Arrest      Non-Cancer
# 66                                  Third degree burn      Non-Cancer
# 67          Chronic intractable migraine without aura      Non-Cancer
# 68                                               Gout      Non-Cancer
# 69                                       Hypertension      Non-Cancer
# 70                      Posttraumatic stress disorder      Non-Cancer
# 71  Fracture of vertebral column without spinal co...      Non-Cancer
# 72                                           COVID-19      Non-Cancer

# %%
# Make a dataframe that contains the primary columns to be used
encounter_df = pd.merge(encounters, patients, left_on = 'PATIENT', right_on = 'Id', how = 'left')
encounter_df_final = pd.merge(encounter_df, diag_rollup_map, left_on = 'REASONDESCRIPTION', right_on = 'disease_name', how = 'left')
encounter_df_final = encounter_df_final[['Id_x', 'PATIENT', 'START', 'CLAIM_YEAR', 'CLAIM_MONTH', 'REASONDESCRIPTION', 'YEAR_OF_BIRTH', 'MARITAL', 'RACE', 'ETHNICITY', 'GENDER', 'rollup', 'rollup_category']]
encounter_df_final['AGE'] = encounter_df_final['CLAIM_YEAR'] - encounter_df_final['YEAR_OF_BIRTH']
encounter_df_final['rollup_category'] = encounter_df_final['rollup_category'].fillna('Unknown')
encounter_df_final['rollup'] = encounter_df_final['rollup'].fillna('Unknown')

# Let's bin the ages of the patients into various age groups
bins = [-float('inf'), 0, 18, 35, 50, 65, 80, 100, float('inf')]  # Adjust these bins as per your specific categories
# Define labels for each bin
labels = ['Invalid', '0-18', '19-35', '36-50', '51-65', '66-80', '80+', 'Invalid_']  # Adjust these labels accordingly

# Create a new column 'Age Category' based on the bins and display the final result
encounter_df_final['Age Group'] = pd.cut(encounter_df_final['AGE'], bins = bins, labels = labels, right = False)
encounter_df_final.head(2)
# Out:
#                                    Id_x                               PATIENT  \
# 0  32c84703-2481-49cd-d571-3899d5820253  3de74169-7f67-9304-91d4-757e0f3a14d2
# 1  c98059da-320a-c0a6-fced-c8815f3e3f39  d9ec2e44-32e9-9148-179a-1653348cc4e2
#
#         START  CLAIM_YEAR  CLAIM_MONTH REASONDESCRIPTION  YEAR_OF_BIRTH  \
# 0  02-01-2011        2011            1               NaN           1928
# 1  03-01-2011        2011            1               NaN           1964
#
#   MARITAL   RACE    ETHNICITY GENDER   rollup rollup_category  AGE Age Group
# 0       M  white  nonhispanic      M  Unknown         Unknown   83       80+
# 1       M  white  nonhispanic      F  Unknown         Unknown   47     36-50

# %%
patient_demo = encounter_df_final.groupby(['MARITAL', 'RACE', 'ETHNICITY', 'GENDER', 'rollup_category', 'Age Group'])['PATIENT'].nunique().reset_index()
patient_demo.columns = ['Marital Status', 'Race', 'Ethnicity', 'Gender', 'Diagnosis Rolup', 'Age Group', 'Patient Count']
patient_demo = patient_demo[patient_demo['Patient Count'] > 0].reset_index(drop = True)
patient_demo.to_csv('Patient_Demographics.csv', index = False)
patient_demo.head(5)
# Out:
# C:\Users\shant\AppData\Local\Temp\ipykernel_18068\4219353192.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   patient_demo = encounter_df_final.groupby(['MARITAL', 'RACE', 'ETHNICITY', 'GENDER', 'rollup_category', 'Age Group'])['PATIENT'].nunique().reset_index()
#   Marital Status   Race Ethnicity Gender Diagnosis Rolup Age Group  \
# 0              M  asian  hispanic      F      Non-Cancer     51-65
# 1              M  asian  hispanic      F      Non-Cancer     66-80
# 2              M  asian  hispanic      F      Non-Cancer       80+
# 3              M  asian  hispanic      F         Unknown     36-50
# 4              M  asian  hispanic      F         Unknown     51-65
#
#    Patient Count
# 0              1
# 1              1
# 2              2
# 3              1
# 4              1

# %% [markdown]
# #### 2. Longitudinal or Monthly Analysis of Patient Trends
#
# Analyse the encounter table on a monthly level, get monthly patient and claim counts for a longitudinal analysis and draw temporal insights on a diagnosis rollup level

# %%
longitudinal_clm_1 = encounter_df_final.groupby(['CLAIM_YEAR', 'CLAIM_MONTH', 'rollup', 'rollup_category'])['Id_x'].nunique().reset_index()
longitudinal_clm_1.columns = ['Claim Year', 'Claim Month', 'Diagnosis Rollup', 'Rollup Category', 'Claim Count']
longitudinal_clm_1 = longitudinal_clm_1[longitudinal_clm_1['Claim Count'] > 0].reset_index(drop = True)

longitudinal_clm_2 = encounter_df_final.groupby(['CLAIM_YEAR', 'CLAIM_MONTH'])['Id_x'].nunique().reset_index()
longitudinal_clm_2['rollup'] = 'Overall'
longitudinal_clm_2['rollup_category'] = 'Overall'
longitudinal_clm_2 = longitudinal_clm_2[['CLAIM_YEAR', 'CLAIM_MONTH', 'rollup', 'rollup_category', 'Id_x']]
longitudinal_clm_2.columns = ['Claim Year', 'Claim Month', 'Diagnosis Rollup', 'Rollup Category', 'Claim Count']
longitudinal_clm_2 = longitudinal_clm_2[longitudinal_clm_2['Claim Count'] > 0].reset_index(drop = True)
longitudinal_clm_2.head(5)

longitudinal_clm = pd.concat([longitudinal_clm_1, longitudinal_clm_2], ignore_index=True)
longitudinal_clm.to_csv('Claim_Monthly.csv', index = False)
longitudinal_clm.head(3)
# Out:
#    Claim Year  Claim Month                Diagnosis Rollup Rollup Category  \
# 0        2011            1     Acute bronchitis (disorder)      Non-Cancer
# 1        2011            1  Alzheimer's disease (disorder)      Non-Cancer
# 2        2011            1                    Colon Cancer          Cancer
#
#    Claim Count
# 0            3
# 1            3
# 2            1

# %%
longitudinal_ptn_1 = encounter_df_final.groupby(['CLAIM_YEAR', 'CLAIM_MONTH', 'rollup_category'])['PATIENT'].nunique().reset_index()
longitudinal_ptn_1.columns = ['Claim Year', 'Claim Month', 'Rollup Category', 'Patient Count']
longitudinal_ptn_1 = longitudinal_ptn_1[longitudinal_ptn_1['Patient Count'] > 0].reset_index(drop = True)
longitudinal_ptn_1.to_csv('Patient_Monthly.csv', index = False)

longitudinal_ptn_2 = encounter_df_final.groupby(['CLAIM_YEAR', 'CLAIM_MONTH'])['PATIENT'].nunique().reset_index()
longitudinal_ptn_2['rollup_category'] = 'Overall'
longitudinal_ptn_2 = longitudinal_ptn_2[['CLAIM_YEAR', 'CLAIM_MONTH', 'rollup_category', 'PATIENT']]
longitudinal_ptn_2.columns = ['Claim Year', 'Claim Month', 'Rollup Category', 'Patient Count']
longitudinal_ptn_2 = longitudinal_ptn_2[longitudinal_ptn_2['Patient Count'] > 0].reset_index(drop = True)

longitudinal_ptn = pd.concat([longitudinal_ptn_1, longitudinal_ptn_2], ignore_index=True)
longitudinal_ptn.to_csv('Patient_Monthly.csv', index = False)
longitudinal_ptn.head(3)
# Out:
#    Claim Year  Claim Month Rollup Category  Patient Count
# 0        2011            1          Cancer              3
# 1        2011            1      Non-Cancer             16
# 2        2011            1         Unknown             52

# %% [markdown]
# ### !!! IMPORTANT NOTE:
#
# 1. The decision to exclude the "Diagnosis Rollup" column from patient counts was made to prevent potential double-counting of patients across multiple Diagnosis rollup categories. Instead, a separate attribute labeled "Overall" was calculated to provide a unified count.
#
# 2. This approach ensures accuracy in calculations when the flat files are utilized in PowerBI, particularly when the tool aggregates data across different filters or slices.
#
# 3. However, this differentiation was not applied to Claim Counts, as claims do not double-count when aggregated across multiple attributes. Nonetheless, an attribute labeled "Overall" was still calculated for completeness.
# ____________________

# %% [markdown]
# #### 3. Payer Level Analysis
#
# Explore the diversity of payers represented in the dataset to understand the range of insurance companies and payment options chosen by patients. This analysis provides insights into the financial aspects of healthcare coverage within the dataset.

# %%
payer_df = pd.merge(encounters, payers, left_on = 'PAYER', right_on = 'Id', how = 'left')
payer_df = pd.merge(payer_df, diag_rollup_map, left_on = 'REASONDESCRIPTION', right_on = 'disease_name', how = 'left')
payer_df = payer_df[['Id_x', 'PATIENT', 'PAYER', 'START', 'CLAIM_YEAR', 'CLAIM_MONTH', 'NAME','REASONDESCRIPTION', 'rollup', 'rollup_category']]
payer_df.head(3)
# Out:
#                                    Id_x                               PATIENT  \
# 0  32c84703-2481-49cd-d571-3899d5820253  3de74169-7f67-9304-91d4-757e0f3a14d2
# 1  c98059da-320a-c0a6-fced-c8815f3e3f39  d9ec2e44-32e9-9148-179a-1653348cc4e2
# 2  4ad28a3a-2479-782b-f29c-d5b3f41a001e  73babadf-5b2b-fee7-189e-6f41ff213e01
#
#                                   PAYER       START  CLAIM_YEAR  CLAIM_MONTH  \
# 0  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76  02-01-2011        2011            1
# 1  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76  03-01-2011        2011            1
# 2  7caa7254-5050-3b5e-9eae-bd5ea30e809c  03-01-2011        2011            1
#
#            NAME REASONDESCRIPTION rollup rollup_category
# 0  NO_INSURANCE               NaN    NaN             NaN
# 1  NO_INSURANCE               NaN    NaN             NaN
# 2      Medicare               NaN    NaN             NaN

# %%
payer_count = payer_df.groupby(['CLAIM_YEAR', 'CLAIM_MONTH', 'NAME', 'rollup_category'])['PATIENT'].nunique().reset_index()
payer_count.columns = ['Claim Year', 'Claim Month', 'Payer Name/Type', 'Diagnosis Rollup', 'Patient Count']
payer_count = payer_count[payer_count['Patient Count'] > 0].reset_index(drop = True)
payer_count.to_csv('Payer_Monthly_Counts.csv', index = False)
payer_count.head(3)
# Out:
#    Claim Year  Claim Month Payer Name/Type Diagnosis Rollup  Patient Count
# 0        2011            1           Aetna       Non-Cancer              2
# 1        2011            1          Anthem       Non-Cancer              2
# 2        2011            1   Dual Eligible       Non-Cancer              1

# %% [markdown]
# #### 4. Procedure Level Analysis
# 1. Types of Procedures: Identify the various types of procedures conducted at the hospital, categorizing them based on their medical nature and purpose.
# 2. Role of Pharmacy (Rx) Data: Pharmacy data is essential for tracking a patient's complete journey, including surgeries, adjuvant therapies, and neo-adjuvant therapies. However, this dataset lacks Pharmacy data, limiting the ability to follow holistic patient treatment paths.
# 3. Scope of Procedure Data: The dataset provides a record of procedures performed, but these procedures may not exclusively relate to cancer treatment or reflect a comprehensive patient journey.

# %%
# Read a manual mapping of procedure rollups (such as Biopsies, X Rays, surgeries, Chemotherapy etc.)
procedure_map = pd.read_csv("procedures_mapping.csv")
procedure_map
# Out:
#                                  procedure_description   procedure_rollup
# 0    Human epidermal growth factor receptor 2 gene ...     Biomarker Test
# 1    Human epidermal growth factor receptor 2 gene ...     Biomarker Test
# 2                                   Biopsy of prostate             Biopsy
# 3                         Biopsy of breast (procedure)             Biopsy
# 4                                      Biopsy of colon             Biopsy
# 5                             Chemotherapy (procedure)              Chemo
# 6    Combined chemotherapy and radiation therapy (p...  Chemo + Radiation
# 7                                          Colonoscopy        Colonoscopy
# 8    High resolution computed tomography of chest w...            CT Scan
# 9                       Electrocardiographic procedure                ECG
# 10                        Echocardiography (procedure)                ECG
# 11                             Mammography (procedure)        Mammography
# 12                 Mammogram - symptomatic (procedure)        Mammography
# 13   Magnetic resonance imaging for measurement of ...                MRI
# 14    Magnetic resonance imaging of breast (procedure)                MRI
# 15                          Renal dialysis (procedure)   Other Procedures
# 16                             Intramuscular injection   Other Procedures
# 17      Diagnostic fiberoptic bronchoscopy (procedure)   Other Procedures
# 18                       Digital examination of rectum   Other Procedures
# 19                            Electrical cardioversion   Other Procedures
# 20   Assessment of health and social care needs (pr...   Other Procedures
# 21       Assessment using Morse Fall Scale (procedure)   Other Procedures
# 22            Screening for domestic abuse (procedure)   Other Procedures
# 23                    Depression screening (procedure)   Other Procedures
# 24   Depression screening using Patient Health Ques...   Other Procedures
# 25   Screening for chromosomal aneuploidy in prenat...   Other Procedures
# 26                 Evaluation of uterine fundal height   Other Procedures
# 27                     Auscultation of the fetal heart   Other Procedures
# 28                                Depression screening   Other Procedures
# 29                                Physical examination   Other Procedures
# 30               Medication Reconciliation (procedure)   Other Procedures
# 31                   Assessment of anxiety (procedure)   Other Procedures
# 32             Assessment of substance use (procedure)   Other Procedures
# 33                Screening for drug abuse (procedure)   Other Procedures
# 34     Measurement of respiratory function (procedure)   Other Procedures
# 35                     Hearing examination (procedure)   Other Procedures
# 36                       Hospice care (regime/therapy)   Other Procedures
# 37                       Bone density scan (procedure)   Other Procedures
# 38                              Alpha-fetoprotein test   Other Procedures
# 39                                 Fetal anatomy study   Other Procedures
# 40                              Spirometry (procedure)   Other Procedures
# 41           Pulmonary rehabilitation (regime/therapy)   Other Procedures
# 42   Assessment using New York Heart Association Cl...   Other Procedures
# 43   Assessment using Alcohol Use Disorders Identif...   Other Procedures
# 44       Placing subject in prone position (procedure)   Other Procedures
# 45           Oxygen administration by mask (procedure)   Other Procedures
# 46   Depression screening using Patient Health Ques...   Other Procedures
# 47                       Patient discharge (procedure)   Other Procedures
# 48                                 Bone immobilization   Other Procedures
# 49           Cardiovascular stress testing (procedure)   Other Procedures
# 50                Catheter ablation of tissue of heart   Other Procedures
# 51   Vaccination for diphtheria  pertussis  and tet...   Other Procedures
# 52                         Urine screening for glucose   Other Procedures
# 53            Hemoglobin / Hematocrit / Platelet count   Other Procedures
# 54                      Sputum examination (procedure)   Other Procedures
# 55                 Heart failure education (procedure)   Other Procedures
# 56                                  Rectal polypectomy   Other Procedures
# 57               Peripheral blood smear interpretation   Other Procedures
# 58                       Review of systems (procedure)   Other Procedures
# 59               Brief general examination (procedure)   Other Procedures
# 60       Streptococcus pneumoniae group B antigen test   Other Procedures
# 61                                   Suture open wound   Other Procedures
# 62     Screening for occult blood in feces (procedure)   Other Procedures
# 63                                          Episiotomy   Other Procedures
# 64                                          Childbirth   Other Procedures
# 65                Physical examination following birth   Other Procedures
# 66                          Throat culture (procedure)   Other Procedures
# 67               Manual pelvic examination (procedure)   Other Procedures
# 68   Cytopathology procedure  preparation of smear ...   Other Procedures
# 69                            Bilateral tubal ligation   Other Procedures
# 70                  Admission to orthopedic department   Other Procedures
# 71                   Urine screening test for diabetes   Other Procedures
# 72                              Chlamydia antigen test   Other Procedures
# 73                             Syphilis infection test   Other Procedures
# 74                             Standard pregnancy test   Other Procedures
# 75                                   Rubella screening   Other Procedures
# 76                 Ultrasound scan for fetal viability   Other Procedures
# 77                                  Urine protein test   Other Procedures
# 78                            Gonorrhea infection test   Other Procedures
# 79                                       Urine culture   Other Procedures
# 80                           Hepatitis C antibody test   Other Procedures
# 81      Measurement of Varicella-zoster virus antibody   Other Procedures
# 82   Cytopathology procedure  preparation of smear ...   Other Procedures
# 83             Hepatitis B Surface Antigen Measurement   Other Procedures
# 84                             Blood typing  RH typing   Other Procedures
# 85           Human immunodeficiency virus antigen test   Other Procedures
# 86                          Skin test for tuberculosis   Other Procedures
# 87                      Physical examination of mother   Other Procedures
# 88                                 Epidural anesthesia   Other Procedures
# 89                                    Cesarean section   Other Procedures
# 90                          Subcutaneous immunotherapy   Other Procedures
# 91              Surgical manipulation of joint of knee   Other Procedures
# 92   Percutaneous mechanical thrombectomy of portal...   Other Procedures
# 93      Insertion of intrauterine contraceptive device   Other Procedures
# 94                    Induced termination of pregnancy   Other Procedures
# 95             Counseling for termination of pregnancy   Other Procedures
# 96    Replacement of contraceptive intrauterine device   Other Procedures
# 97                          Pregnancy termination care   Other Procedures
# 98                    Physical exam following abortion   Other Procedures
# 99              Monitoring of patient (regime/therapy)   Other Procedures
# 100                              Augmentation of labor   Other Procedures
# 101              Removal of subcutaneous contraceptive   Other Procedures
# 102                  Information gathering (procedure)   Other Procedures
# 103            Insertion of subcutaneous contraceptive   Other Procedures
# 104                         Medical induction of labor   Other Procedures
# 105                     Injection of tetanus antitoxin   Other Procedures
# 106                           RhD passive immunization   Other Procedures
# 107             Admission to trauma surgery department   Other Procedures
# 108                        Spontaneous breech delivery   Other Procedures
# 109   Referral to home health care service (procedure)   Other Procedures
# 110                              Instrumental delivery   Other Procedures
# 111  Insertion of biventricular implantable cardiov...   Other Procedures
# 112           Computed tomography of chest and abdomen   Other Procedures
# 113                      Sputum microscopy (procedure)   Other Procedures
# 114                     Removal of intrauterine device   Other Procedures
# 115  Resuscitation using intravenous fluid (procedure)   Other Procedures
# 116              Transfer to stepdown unit (procedure)   Other Procedures
# 117             Teleradiotherapy procedure (procedure)   Other Procedures
# 118                         Premature birth of newborn   Other Procedures
# 119  Fine needle aspiration biopsy of lung (procedure)   Other Procedures
# 120                                          Vasectomy   Other Procedures
# 121                         Extraction of wisdom tooth   Other Procedures
# 122                  Movement therapy (regime/therapy)   Other Procedures
# 123  Cognitive and behavioral therapy (regime/therapy)   Other Procedures
# 124  Ultrasonography of abdomen  right upper quadra...   Other Procedures
# 125                                         Intubation   Other Procedures
# 126               Laparoscopic Removal of Gall Bladder   Other Procedures
# 127                 Psychosocial care (regime/therapy)   Other Procedures
# 128   Ultrasonography of bilateral breasts (procedure)   Other Procedures
# 129  Intravenous blood transfusion of packed cells ...   Other Procedures
# 130             Sentinel lymph node biopsy (procedure)   Other Procedures
# 131                          Thoracentesis (procedure)   Other Procedures
# 132                 Percutaneous coronary intervention   Other Procedures
# 133                    Coronary artery bypass grafting   Other Procedures
# 134                   Antenatal RhD antibody screening   Other Procedures
# 135                             Allergy screening test   Other Procedures
# 136                                       Appendectomy   Other Procedures
# 137                  Screening mammography (procedure)   Other Procedures
# 138                  Nasal sinus endoscopy (procedure)   Other Procedures
# 139                             Admission to burn unit   Other Procedures
# 140                    Admission to long stay hospital   Other Procedures
# 141                Mental health screening (procedure)   Other Procedures
# 142                Suicide risk assessment (procedure)   Other Procedures
# 143                        Face mask (physical object)   Other Procedures
# 144                           Admit to ICU (procedure)   Other Procedures
# 145         Insertion of endotracheal tube (procedure)   Other Procedures
# 146  Controlled ventilation procedure and therapy  ...   Other Procedures
# 147                           Hemodialysis (procedure)   Other Procedures
# 148        Methotrexate injection into tubal pregnancy   Other Procedures
# 149                      Microbial culture (procedure)   Other Procedures
# 150                         Partial resection of colon  Resection Surgery
# 151                                      Prostatectomy  Resection Surgery
# 152              Excision of breast tissue (procedure)  Resection Surgery
# 153        Excision of sentinel lymph node (procedure)  Resection Surgery
# 154                   Lumpectomy of breast (procedure)  Resection Surgery
# 155                      Plain chest X-ray (procedure)              X-Ray
# 156                                    Upper arm X-ray              X-Ray
# 157                                        Ankle X-ray              X-Ray
# 158                                        Chest X-ray              X-Ray
# 159                                     Clavicle X-ray              X-Ray
# 160                                         Knee X-ray              X-Ray
# 161                                     X-ray or wrist              X-Ray
# 162                                       Pelvis X-ray              X-Ray

# %%
procedure_df = pd.merge(procedures, procedure_map, left_on = 'DESCRIPTION', right_on = 'procedure_description', how = 'left')
procedure_df = pd.merge(procedure_df, diag_rollup_map, left_on = 'REASONDESCRIPTION', right_on = 'disease_name', how = 'left')
procedure_df = procedure_df[['PATIENT', 'ENCOUNTER', 'START', 'PROC_YEAR', 'PROC_MONTH', 'DESCRIPTION', 'REASONDESCRIPTION', 'procedure_rollup', 'rollup_category']]
procedure_df.head(3)
# Out:
#                                 PATIENT                             ENCOUNTER  \
# 0  3de74169-7f67-9304-91d4-757e0f3a14d2  32c84703-2481-49cd-d571-3899d5820253
# 1  d9ec2e44-32e9-9148-179a-1653348cc4e2  c98059da-320a-c0a6-fced-c8815f3e3f39
# 2  d856d6e6-4c98-e7a2-129b-44076c63d008  2cfd4ddd-ad13-fe1e-528b-15051cea2ec3
#
#         START  PROC_YEAR  PROC_MONTH  \
# 0  2011-01-02       2011           1
# 1  2011-01-03       2011           1
# 2  2011-01-04       2011           1
#
#                                          DESCRIPTION  \
# 0                         Renal dialysis (procedure)
# 1                            Intramuscular injection
# 2  Combined chemotherapy and radiation therapy (p...
#
#           REASONDESCRIPTION   procedure_rollup rollup_category
# 0                       NaN   Other Procedures             NaN
# 1                       NaN   Other Procedures             NaN
# 2  Malignant tumor of colon  Chemo + Radiation          Cancer

# %%
procedure_count = procedure_df.groupby(['PROC_YEAR', 'PROC_MONTH', 'procedure_rollup', 'rollup_category'])['PATIENT'].nunique().reset_index()
procedure_count.columns = ['Procedure Year', 'Procedure Month', 'Procedure Rollup', 'Diagnosis Rollup', 'Patient Count']
procedure_count = procedure_count[procedure_count['Patient Count'] > 0].reset_index(drop = True)
procedure_count.to_csv('Procedure_Monthly_Counts.csv', index = False)
procedure_count.head(3)
# Out:
#    Procedure Year  Procedure Month   Procedure Rollup Diagnosis Rollup  \
# 0            2011                1  Chemo + Radiation           Cancer
# 1            2011                1                MRI           Cancer
# 2            2011                1   Other Procedures           Cancer
#
#    Patient Count
# 0              6
# 1              1
# 2              1

# %% [markdown]
# This concludes the preliminary stage of the EDA. The flat files generated will be imported into PowerBI for making a report where further transformations might occur. Since the "business ask" is open ended the PowerBI report will focus on providing a complete look into the entire data structure in an intuitive easy to use manner. Following flat files will be used:
# 1. Fill_Rates.csv
# 2. Patient_Demographics.csv
# 3. Claim_Monthly.csv
# 4. Patient_Monthly.csv
# 5. Payer_Monthly_Counts.csv
# 6. Procedure_Monthly_Counts.csv
#
# ________________
